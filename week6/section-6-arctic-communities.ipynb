# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
# Import Arctic communities GeoJSON directly from URL
filepath = os.path.join("data", "arctic_communities.geojson")
df = gpd.read_file(filepath)
df.head()
# Out:
#                       admin country  n_communities  \
# 0  United States of America      US            115
# 1            United Kingdom      GB             96
# 2                    Sweden      SE            133
# 3                    Russia      RU            774
# 4                    Norway      NO             48
#
#                                             geometry
# 0  MULTIPOLYGON (((-132.74687 56.52568, -132.7576...
# 1  MULTIPOLYGON (((-2.66768 51.62300, -2.74214 51...
# 2  MULTIPOLYGON (((19.07646 57.83594, 18.99375 57...
# 3  MULTIPOLYGON (((145.88154 43.45952, 145.89561 ...
# 4  MULTIPOLYGON (((20.62217 69.03687, 20.49199 69...

# %% [markdown]
# ## Brainstorming
# 1. group by country code
# 2.

# %%
df.geom_type
# Out:
# 0     MultiPolygon
# 1     MultiPolygon
# 2     MultiPolygon
# 3     MultiPolygon
# 4     MultiPolygon
# 5     MultiPolygon
# 6          Polygon
# 7          Polygon
# 8     MultiPolygon
# 9     MultiPolygon
# 10    MultiPolygon
# 11    MultiPolygon
# 12    MultiPolygon
# 13    MultiPolygon
# 14         Polygon
# dtype: object

# %% [markdown]
# `df.geom_type` tells us the vector data type of the data, in this case the data are stored as points

# %%
def check_polygons(geodataframe):
    if df.geom_type.unique() > 1:
        print(f"Multiple feature types: {df.geom_type.unique()}")
    else:
        print(f"All features are: {df.geom_type.unique()}")

# %%
check_polygons(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 check_polygons(df)
#
# Cell In[44], line 2, in check_polygons(geodataframe)
#       1 def check_polygons(geodataframe):
# ----> 2     if df.geom_type.unique() > 1:
#       3         print(f"Multiple feature types: {df.geom_type.unique()}")
#       4     else:
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
# Explode polygons
df = df.explode(columns = "geometry", index_parts=False).reset_index()

# %%
check_polygons(df)

# %%
# Compute minumum y-coordinate
type(df.iloc[0])

# %%
# Select geometry of the first row of df
type(df.iloc[0].geometry)

# %%
df.iloc[0, "geometry"].bounds[1]

# %%
def min_y(i):
    y = i.geometry.bounds[1]
    return(y)
